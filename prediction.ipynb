# %%
import joblib
import numpy as np

# Load model
model = joblib.load("models/model.pkl")

# Example input (replace with real values)
sample = np.array([[0]*30])  # 30 features

prediction = model.predict(sample)

print("Prediction:", prediction)
# Out:
# Prediction: [0]
# g:\fraud-detection\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
